# %% [markdown]
# <a href="https://colab.research.google.com/github/antonyYG/Numpy_pandas/blob/main/Img.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trabajando con imagenes

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

path = "/content/img_prueba.jpg"
img = cv2.imread(path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)
a1,a2 = np.split()
plt.imshow(img_rgb)
